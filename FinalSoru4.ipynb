# %%
import pandas as pd

xi = [15,15,16,19,19,20,20,21,22,28,35,40,41,42,43,44,60,61,65]
c1 = 16
c2 = 22

for x in range(4):
    
    a=0
    b=0
    
    mesafe = []
    mesafe2 = []
    toplam1=0
    toplam2=0
    
    merkez=[]
    
    Nearestcluster=[]
    i=0
    j=0

    for i in xi:
        tanimx=0
        tanimy=0
        x= abs(i-c1)
        y= abs(i-c2)
        mesafe.append(x)
        mesafe2.append(y)
        if x>y:
            tanimy+=2
            Nearestcluster.append(tanimx)
            toplam2+=c2+i
            i+=2
        elif y>x:
            tanimx+=1
            Nearestcluster.append(tanimx)
            toplam1+=c1+i
            j+=2
        else:
            tanimy+=2
            Nearestcluster.append(tanimy)
            toplam2+=c2+i
            i+=2
            
    deger=[]
    deger2=[]
    deger2=toplam2/i
    deger=toplam1/j
    

    for n in  Nearestcluster:
        if n== 1:
            merkez.append(deger)
        else:
            merkez.append(deger2)
     

    a = {
         "xi":xi,
         "c1":c1,
         "c2":c2,
         "mesafe":mesafe,
         "mesafe2":mesafe2,
         "Nearestcluster":Nearestcluster,
         "sonmerkez":merkez,
        }

    df = pd.DataFrame(a)
         
    print(df)
# Out:
#     xi  c1  c2  mesafe  mesafe2  Nearestcluster  sonmerkez
# 0   15  16  22       1        7               1  15.666667
# 1   15  16  22       1        7               1  15.666667
# 2   16  16  22       0        6               1  15.666667
# 3   19  16  22       3        3               2  13.910448
# 4   19  16  22       3        3               2  13.910448
# 5   20  16  22       4        2               0  13.910448
# 6   20  16  22       4        2               0  13.910448
# 7   21  16  22       5        1               0  13.910448
# 8   22  16  22       6        0               0  13.910448
# 9   28  16  22      12        6               0  13.910448
# 10  35  16  22      19       13               0  13.910448
# 11  40  16  22      24       18               0  13.910448
# 12  41  16  22      25       19               0  13.910448
# 13  42  16  22      26       20               0  13.910448
# 14  43  16  22      27       21               0  13.910448
# ...
